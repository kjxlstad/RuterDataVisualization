# %%
import pandas as pd
from matplotlib import pyplot as plot
data = pd.read_csv("../datasets/Ruter_data.csv", delimiter=';')
data.shape
# Out:
# (6000, 17)

# %%
# Had some trouble getting dates in proper format (ddmmyyyy), so i made sure it worked every time with this method
def format_date(date) : 
    d, m, y = map(int, date.split('/'))
    return pd.Timestamp(day=d, month=m, year=y)

def clean_hour(time) : return pd.Timestamp(str(int(time[0:2]) % 24) + time[2:])

def delay(actual, expected) : return clean_hour(actual) - clean_hour(expected)

# %%
data = data[['Kommune', 'Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra', 'Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra']]
# We need to remove the entries where the bus never made it, indicated by actual arrival being ':'
#len(data['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'][0])
#data[len(data.Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra) == 8]
for i in range(len(data)):
    print(len(data['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'][i]))
#data.insert(3, 'Delay', [delay(data['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'][i], data['Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra'][i]) for i in range(len(data))], True)
#data
#[data['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'][i] for i in range(len(data))]
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 1
# 8
# 8
# 8
# 8
# ...
